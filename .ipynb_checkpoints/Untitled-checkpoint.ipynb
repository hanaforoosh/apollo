# %%
import networkx as nx
import pickle
import matplotlib.pyplot as plt

# %%
strategy_p = pickle.load(open('Data/Found_patterns/Abstract Factory_planning.p','rb'))
strategy_c = pickle.load(open('Data/Found_patterns/Abstract Factory_control.p','rb'))
print(len(strategy_c))
print(len(strategy_p))
# Out:
# 3
# 2

# %%
s1 = strategy[0]
G = pickle.load(open('Data/planning_graph.p','rb'))
l = []
for s in s1.keys():
    l.append(s)
G1 = G.subgraph(s1.keys())
nx.draw(G1,with_labels=True)
plt.show()
