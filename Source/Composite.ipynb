# %% [markdown]
# ### Imports

# %%
import networkx as nx
import networkx.algorithms.isomorphism as iso
import pickle
from functools import reduce

# %% [markdown]
# ### Graphs initialization

# %%
# main (code) graph
ctrl = pickle.load(open('../Data/ctrl_graph.p','rb'))
planning = pickle.load(open('../Data/planning_graph.p','rb'))

# %% [markdown]
# ### 1. Change this
# # ↓↓↓   ↓↓↓

# %%
# Composite patten
pattern_name='Composite'
pattern = nx.DiGraph()
pattern.add_edge('Leaf','component',type='Generalization')
pattern.add_edge('Composite','component',type='Generalization')

# %% [markdown]
# ### Graphs visualizations [Optional]

# %%
# ctrl graph
pos=nx.spring_layout(ctrl)
nx.draw_networkx_edge_labels(ctrl,pos)
nx.draw(ctrl,pos,with_labels=True)

# %%
# planning graph
pos=nx.spring_layout(planning)
nx.draw_networkx_edge_labels(planning,pos)
nx.draw(planning,pos,with_labels=True)

# %%
# pattern graph
pos=nx.spring_layout(pattern)
nx.draw_networkx_edge_labels(pattern,pos)
nx.draw(pattern,pos,with_labels=True)

# %% [markdown]
# ### Finding matched patterns

# %%
# in ctrl graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
ctrl_DiGM = iso.DiGraphMatcher(ctrl,pattern,edge_match=nm)
#ctrl_DiGM.subgraph_is_isomorphic()
ctrl_subgraphs = [graph for graph in ctrl_DiGM.subgraph_isomorphisms_iter()]
print (ctrl_subgraphs)
# Out:
# [{'MPCControllerTest': 'Leaf', 'ControlTestBase': 'component', 'SimpleControlTest': 'Composite'}, {'MPCControllerTest': 'Leaf', 'ControlTestBase': 'component', 'RelativePositionTest': 'Composite'}, {'PIDBCController': 'Leaf', 'PIDController': 'component', 'PIDICController': 'Composite'}, {'RelativePositionTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite'}, {'RelativePositionTest': 'Leaf', 'ControlTestBase': 'component', 'SimpleControlTest': 'Composite'}, {'LonController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite'}, {'LonController': 'Leaf', 'Controller': 'component', 'MPCController': 'Composite'}, {'PIDICController': 'Leaf', 'PIDController': 'component', 'PIDBCController': 'Composite'}, {'SimpleControlTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite'}, {'SimpleControlTest': 'Leaf', 'ControlTestBase': 'component', 'RelativePositionTest': 'Composite'}, {'LatController': 'Leaf', 'Controller': 'component', 'MPCController': 'Composite'}, {'LatController': 'Leaf', 'Controller': 'component', 'LonController': 'Composite'}, {'MPCController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite'}, {'MPCController': 'Leaf', 'Controller': 'component', 'LonController': 'Composite'}]

# %%
# in planning graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
planning_DiGM = iso.DiGraphMatcher(planning,pattern,edge_match=nm)
#planning_DiGM.subgraph_is_isomorphic()
planning_subgraphs = [graph for graph in planning_DiGM.subgraph_isomorphisms_iter()]
print (planning_subgraphs)
# Out:
# [{'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyPullOverStageSlowDown': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightProtectedStageIntersectionCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyStopStageStandby': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'ParkAndGoStageCheck': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyPullOverStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'ParkAndGoStageCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'BareIntersectionUnprotectedStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightProtectedStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StageParking': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StageApproachingParkingSpot': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'ParkAndGoStageAdjust': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'PullOverStageRetryParking': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'PullOverStageRetryApproachParking': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedRightTurnStageCreep': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageCreep': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedLeftTurnStageCreep': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'LaneFollowStage': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'ParkAndGoStagePreCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StopSignUnprotectedStageCreep': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedLeftTurnStageIntersectionCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyStopStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'BareIntersectionUnprotectedStageIntersectionCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyPullOverStageStandby': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedLeftTurnStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'PullOverStageApproach': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StopSignUnprotectedStageStop': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StopSignUnprotectedStagePreStop': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedRightTurnStageStop': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'StopSignUnprotectedStageIntersectionCruise': 'Composite'}, {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'TrafficLightUnprotectedRightTurnStageIntersectionCruise': 'Composite'}, {'QpSplineReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'DiscretePointsReferenceLineSmoother': 'Composite'}, {'QpSplineReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'SpiralReferenceLineSmoother': 'Composite'}, {'RTKReplayPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'PublicRoadPlanner': 'Composite'}, {'RTKReplayPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'LatticePlanner': 'Composite'}, {'RTKReplayPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'NaviPlanner': 'Composite'}, {'StopSign': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite'}, {'StopSign': 'Leaf', 'TrafficRule': 'component', 'TrafficLight': 'Composite'}, {'StopSign': 'Leaf', 'TrafficRule': 'component', 'KeepClear': 'Composite'}, {'S ...

# %% [markdown]
# ### Merge patterns

# %%
# function definitions
def get_key(val,l): 
    for key, value in l.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

def mergeList(subList,pat):
    result=[]
    while(len(subList)>0):
        res1 = []
        res1.append(subList[0])
        for j in range(1,len(subList)):
            flag = True
            for k in pat:
                if(get_key(k,subList[0])!=get_key(k,subList[j])):
                    flag = False
            if(flag==True):
                res1.append(subList[j])
        result.append(res1)
        l3 = [x for x in subList if x not in res1]
        subList = l3
    return result

def merge(disconnected_patterns,fixed):
    lst = mergeList(disconnected_patterns,fixed)
    return list(map(lambda item: dict(item[0],**item[1]) if len(item)>1 else item[0],lst))

# %% [markdown]
# ### 2. Change this
# # ↓↓↓   ↓↓↓

# %%
fixed_parts ={'Leaf','component','component'}

# %%
final_planning_subgraphs=merge(planning_subgraphs,fixed_parts)
final_ctrl_subgraphs=merge(ctrl_subgraphs,fixed_parts)
print('planning :\n',*final_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*final_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyPullOverStageSlowDown': 'Composite', 'TrafficLightProtectedStageIntersectionCruise': 'Composite'}
# {'QpSplineReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'DiscretePointsReferenceLineSmoother': 'Composite', 'SpiralReferenceLineSmoother': 'Composite'}
# {'RTKReplayPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'PublicRoadPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'StopSign': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'TrafficLight': 'Composite'}
# {'YieldSignScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'ActiveSetSpline2dSolver': 'Leaf', 'Spline2dSolver': 'component', 'OsqpSpline2dSolver': 'Composite'}
# {'PiecewiseJerkSpeedOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PathTimeHeuristicOptimizer': 'Composite', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Composite'}
# {'PathTimeHeuristicOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Composite', 'PiecewiseJerkSpeedOptimizer': 'Composite'}
# {'PiecewiseTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'QuinticSpiralPath': 'Leaf', 'QuinticPolynomialCurve1d': 'component', 'QuinticSpiralPathWithDerivation': 'Composite'}
# {'SpeedDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'BareIntersectionUnprotectedScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'YieldSignScenario': 'Composite'}
# {'EmergencyPullOverScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'StageParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ValetParkingScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'Rerouting': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'QuinticSpiralPathWithDerivation': 'Leaf', 'QuinticPolynomialCurve1d': 'component', 'QuinticSpiralPath': 'Composite'}
# {'PiecewiseJerkSpeedProblem': 'Leaf', 'PiecewiseJerkProblem': 'component', 'PiecewiseJerkPathProblem': 'Composite'}
# {'StageApproachingParkingSpot': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'SpiralReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'DiscretePointsReferenceLineSmoother': 'Composite', 'QpSplineReferenceLineSmoother': 'Composite'}
# {'ConstantJerkTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'StandingStillTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'KeepClear': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'StopSignUnprotectedStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'SunnyvaleLoopTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'GarageTest': 'Composite'}
# {'TrafficLightProtectedScenario': 'Leaf', 'Scenario': 'component', 'BareIntersectionUnprotectedScenario': 'Composite', 'YieldSignScenario': 'Composite'}
# {'EmergencyPullOverStageStandby': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OpenSpaceRoiDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'TrafficLight': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'ParkAndGoScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'StopSignUnprotectedStageStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'DistanceApproachIPOPTCUDAInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'EmergencyStopScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PathDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'StopSignUnprotectedStagePreStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PathReuseDecider': 'Leaf', 'Decider': 'component', 'PathLaneBorrowDecider': 'Composite', 'STBoundsDecider': 'Composite'}
# {'EmergencyPullOverStageSlowDown': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'TrafficLightProtectedStageIntersectionCruise': 'Composite'}
# {'NaviPathDecider': 'Leaf', 'NaviTask': 'component', 'NaviSpeedDecider': 'Composite'}
# {'NaviPlanning': 'Leaf', 'PlanningBase': 'component', 'OnLanePlanning': 'Composite'}
# {'GarageTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'SunnyvaleLoopTest': 'Composite'}
# {'OpenSpaceTrajectoryPartition': 'Leaf', 'TrajectoryOptimizer': 'component', 'OpenSpaceTrajectoryProvider': 'Composite'}
# {'EmergencyPullOverStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'LaneChangeDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'DiscretePointsReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'SpiralReferenceLineSmoother': 'Composite', 'QpSplineReferenceLineSmoother': 'Composite'}
# {'DistanceApproachIPOPTRelaxEndSlackInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'LatticePlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'NaviPlanner': 'Composite'}
# {'BareIntersectionUnprotectedStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TrajectoryOptimizer': 'Leaf', 'Task': 'component', 'PathOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'OnLanePlannerDispatcher': 'Leaf', 'PlannerDispatcher': 'component', 'NaviPlannerDispatcher': 'Composite'}
# {'CubicPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'QuinticPolynomialCurve1d': 'Composite', 'QuarticPolynomialCurve1d': 'Composite'}
# {'PiecewiseJerkSpeedNonlinearOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PiecewiseJerkSpeedOptimizer': 'Composite', 'PathTimeHeuristicOptimizer': 'Composite'}
# {'NaviSpeedDecider': 'Leaf', 'NaviTask': 'component', 'NaviPathDecider': 'Composite'}
# {'RuleBasedStopDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'OpenSpaceFallbackDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'DistanceApproachIPOPTFixedTsInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'PiecewiseAccelerationTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseTrajectory1d': 'Composite'}
# {'PullOverStageRetryApproachParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'LatticeTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'NaviPlannerDispatcher': 'Leaf', 'PlannerDispatcher': 'component', 'OnLanePlannerDispatcher': 'Composite'}
# {'PolynomialCurve1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'NaviPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ReferenceLineEnd': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'DistanceApproachIPOPTInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTFixedDualInterface': 'Composite', 'DistanceApproachIPOPTRelaxEndInterface': 'Composite'}
# {'DistanceApproachIPOPTFixedDualInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTRelaxEndInterface': 'Composite'}
# {'DistanceApproachIPOPTRelaxEndInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'PiecewiseJerkPathProblem': 'Leaf', 'PiecewiseJerkProblem': 'component', 'PiecewiseJerkSpeedProblem': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PathAssessmentDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'PiecewiseQuinticSpiralPath': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'Destination': 'Leaf', 'TrafficRule': 'component', 'StopSign': 'Composite', 'TrafficLight': 'Composite'}
# {'TrafficLightProtectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'NavigationModeTest': 'Leaf', 'PlanningTestBase': 'component', 'SunnyvaleLoopTest': 'Composite', 'GarageTest': 'Composite'}
# {'SunnyvaleBigLoopTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'SunnyvaleLoopTest': 'Composite'}
# {'PathBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'ParkAndGoStageCheck': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'QuinticPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'CubicPolynomialCurve1d': 'Composite', 'QuarticPolynomialCurve1d': 'Composite'}
# {'TrafficLightProtectedStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OpenSpacePreStopDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'StopSignUnprotectedScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PublicRoadPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'LaneFollowScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'ParkAndGoStageAdjust': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PullOverStageRetryParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ConstantDecelerationTrajectory1d': 'Leaf', 'Curve1d': 'component', 'PiecewiseAccelerationTrajectory1d': 'Composite', 'PiecewiseTrajectory1d': 'Composite'}
# {'PathLaneBorrowDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'STBoundsDecider': 'Composite'}
# {'SpeedBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'SpeedOptimizer': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'QuarticPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'QuinticPolynomialCurve1d': 'Composite', 'CubicPolynomialCurve1d': 'Composite'}
# {'LaneFollowStage': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ParkAndGoStagePreCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'EmergencyStopStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TestLearningModelScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PathOptimizer': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'CreepDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OsqpSpline1dSolver': 'Leaf', 'Spline1dSolver': 'component', 'ActiveSetSpline1dSolver': 'Composite'}
# {'EmergencyStopStageStandby': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ParkAndGoStageCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OpenSpaceTrajectoryProvider': 'Leaf', 'TrajectoryOptimizer': 'component', 'OpenSpaceTrajectoryPartition': 'Composite'}
# {'BacksideVehicle': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'Decider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'YieldSignStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OsqpSpline2dSolver': 'Leaf', 'Spline2dSolver': 'component', 'ActiveSetSpline2dSolver': 'Composite'}
# {'YieldSign': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'NarrowStreetUTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'RssDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'BareIntersectionUnprotectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'Crosswalk': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'PiecewiseJerkTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'STBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'ActiveSetSpline1dSolver': 'Leaf', 'Spline1dSolver': 'component', 'OsqpSpline1dSolver': 'Composite'}
# {'OnLanePlanning': 'Leaf', 'PlanningBase': 'component', 'NaviPlanning': 'Composite'}
# {'PullOverScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PullOverStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'StopSignUnprotectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
#
#
# Control :
#
# {'MPCControllerTest': 'Leaf', 'ControlTestBase': 'component', 'SimpleControlTest': 'Composite', 'RelativePositionTest': 'Composite'}
# {'PIDBCController': 'Leaf', 'PIDController': 'component', 'PIDICController': 'Composite'}
# {'RelativePositionTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite', 'SimpleControlTest': 'Composite'}
# {'LonController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite', 'MPCController': 'Composite'}
# {'PIDICController': 'Leaf', 'PIDController': 'component', 'PIDBCController': 'Composite'}
# {'SimpleControlTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite', 'RelativePositionTest': 'Composite'}
# {'LatController': 'Leaf', 'Controller': 'component', 'MPCController': 'Composite', 'LonController': 'Composite'}
# {'MPCController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite', 'LonController': 'Composite'}

# %% [markdown]
# ### Pruning

# %%
variable_parts = set(pattern.nodes())-fixed_parts
pruned_planning_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_planning_subgraphs))
pruned_ctrl_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_ctrl_subgraphs))
print('planning :\n',*pruned_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*pruned_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'YieldSignStageApproach': 'Leaf', 'Stage': 'component', 'EmergencyPullOverStageSlowDown': 'Composite', 'TrafficLightProtectedStageIntersectionCruise': 'Composite'}
# {'QpSplineReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'DiscretePointsReferenceLineSmoother': 'Composite', 'SpiralReferenceLineSmoother': 'Composite'}
# {'RTKReplayPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'PublicRoadPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'StopSign': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'TrafficLight': 'Composite'}
# {'YieldSignScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PiecewiseJerkSpeedOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PathTimeHeuristicOptimizer': 'Composite', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Composite'}
# {'PathTimeHeuristicOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Composite', 'PiecewiseJerkSpeedOptimizer': 'Composite'}
# {'PiecewiseTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'SpeedDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'BareIntersectionUnprotectedScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'YieldSignScenario': 'Composite'}
# {'EmergencyPullOverScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'StageParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ValetParkingScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'Rerouting': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'StageApproachingParkingSpot': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'SpiralReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'DiscretePointsReferenceLineSmoother': 'Composite', 'QpSplineReferenceLineSmoother': 'Composite'}
# {'ConstantJerkTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'StandingStillTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'KeepClear': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'StopSignUnprotectedStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'SunnyvaleLoopTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'GarageTest': 'Composite'}
# {'TrafficLightProtectedScenario': 'Leaf', 'Scenario': 'component', 'BareIntersectionUnprotectedScenario': 'Composite', 'YieldSignScenario': 'Composite'}
# {'EmergencyPullOverStageStandby': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OpenSpaceRoiDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'TrafficLight': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'ParkAndGoScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'StopSignUnprotectedStageStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'DistanceApproachIPOPTCUDAInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'EmergencyStopScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PathDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'StopSignUnprotectedStagePreStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PathReuseDecider': 'Leaf', 'Decider': 'component', 'PathLaneBorrowDecider': 'Composite', 'STBoundsDecider': 'Composite'}
# {'EmergencyPullOverStageSlowDown': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'TrafficLightProtectedStageIntersectionCruise': 'Composite'}
# {'GarageTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'SunnyvaleLoopTest': 'Composite'}
# {'EmergencyPullOverStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'LaneChangeDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'DiscretePointsReferenceLineSmoother': 'Leaf', 'ReferenceLineSmoother': 'component', 'SpiralReferenceLineSmoother': 'Composite', 'QpSplineReferenceLineSmoother': 'Composite'}
# {'DistanceApproachIPOPTRelaxEndSlackInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'LatticePlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'NaviPlanner': 'Composite'}
# {'BareIntersectionUnprotectedStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TrajectoryOptimizer': 'Leaf', 'Task': 'component', 'PathOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'CubicPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'QuinticPolynomialCurve1d': 'Composite', 'QuarticPolynomialCurve1d': 'Composite'}
# {'PiecewiseJerkSpeedNonlinearOptimizer': 'Leaf', 'SpeedOptimizer': 'component', 'PiecewiseJerkSpeedOptimizer': 'Composite', 'PathTimeHeuristicOptimizer': 'Composite'}
# {'RuleBasedStopDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'OpenSpaceFallbackDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'DistanceApproachIPOPTFixedTsInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'PiecewiseAccelerationTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseTrajectory1d': 'Composite'}
# {'PullOverStageRetryApproachParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'LatticeTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'PolynomialCurve1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'NaviPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ReferenceLineEnd': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'DistanceApproachIPOPTInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTFixedDualInterface': 'Composite', 'DistanceApproachIPOPTRelaxEndInterface': 'Composite'}
# {'DistanceApproachIPOPTFixedDualInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTRelaxEndInterface': 'Composite'}
# {'DistanceApproachIPOPTRelaxEndInterface': 'Leaf', 'DistanceApproachInterface': 'component', 'DistanceApproachIPOPTInterface': 'Composite', 'DistanceApproachIPOPTFixedDualInterface': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PathAssessmentDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'PiecewiseQuinticSpiralPath': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'Destination': 'Leaf', 'TrafficRule': 'component', 'StopSign': 'Composite', 'TrafficLight': 'Composite'}
# {'TrafficLightProtectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'NavigationModeTest': 'Leaf', 'PlanningTestBase': 'component', 'SunnyvaleLoopTest': 'Composite', 'GarageTest': 'Composite'}
# {'SunnyvaleBigLoopTest': 'Leaf', 'PlanningTestBase': 'component', 'NavigationModeTest': 'Composite', 'SunnyvaleLoopTest': 'Composite'}
# {'PathBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'ParkAndGoStageCheck': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'QuinticPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'CubicPolynomialCurve1d': 'Composite', 'QuarticPolynomialCurve1d': 'Composite'}
# {'TrafficLightProtectedStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'OpenSpacePreStopDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'StopSignUnprotectedScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PublicRoadPlanner': 'Leaf', 'PlannerWithReferenceLine': 'component', 'RTKReplayPlanner': 'Composite', 'LatticePlanner': 'Composite'}
# {'LaneFollowScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'ParkAndGoStageAdjust': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'PullOverStageRetryParking': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ConstantDecelerationTrajectory1d': 'Leaf', 'Curve1d': 'component', 'PiecewiseAccelerationTrajectory1d': 'Composite', 'PiecewiseTrajectory1d': 'Composite'}
# {'PathLaneBorrowDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'STBoundsDecider': 'Composite'}
# {'SpeedBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'SpeedOptimizer': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'TrafficLightUnprotectedLeftTurnStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'QuarticPolynomialCurve1d': 'Leaf', 'PolynomialCurve1d': 'component', 'QuinticPolynomialCurve1d': 'Composite', 'CubicPolynomialCurve1d': 'Composite'}
# {'LaneFollowStage': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ParkAndGoStagePreCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'EmergencyStopStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'TestLearningModelScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PathOptimizer': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'CreepDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageStop': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'EmergencyStopStageStandby': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'ParkAndGoStageCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'BacksideVehicle': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'Decider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'SpeedDecider': 'Composite'}
# {'TrafficLightUnprotectedRightTurnStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'YieldSignStageCreep': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'YieldSign': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'NarrowStreetUTurnScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'RssDecider': 'Leaf', 'Task': 'component', 'TrajectoryOptimizer': 'Composite', 'PathOptimizer': 'Composite'}
# {'BareIntersectionUnprotectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'Crosswalk': 'Leaf', 'TrafficRule': 'component', 'Destination': 'Composite', 'StopSign': 'Composite'}
# {'PiecewiseJerkTrajectory1d': 'Leaf', 'Curve1d': 'component', 'ConstantDecelerationTrajectory1d': 'Composite', 'PiecewiseAccelerationTrajectory1d': 'Composite'}
# {'STBoundsDecider': 'Leaf', 'Decider': 'component', 'PathReuseDecider': 'Composite', 'PathLaneBorrowDecider': 'Composite'}
# {'PullOverScenario': 'Leaf', 'Scenario': 'component', 'TrafficLightProtectedScenario': 'Composite', 'BareIntersectionUnprotectedScenario': 'Composite'}
# {'PullOverStageApproach': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
# {'StopSignUnprotectedStageIntersectionCruise': 'Leaf', 'Stage': 'component', 'YieldSignStageApproach': 'Composite', 'EmergencyPullOverStageSlowDown': 'Composite'}
#
#
# Control :
#
# {'MPCControllerTest': 'Leaf', 'ControlTestBase': 'component', 'SimpleControlTest': 'Composite', 'RelativePositionTest': 'Composite'}
# {'RelativePositionTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite', 'SimpleControlTest': 'Composite'}
# {'LonController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite', 'MPCController': 'Composite'}
# {'SimpleControlTest': 'Leaf', 'ControlTestBase': 'component', 'MPCControllerTest': 'Composite', 'RelativePositionTest': 'Composite'}
# {'LatController': 'Leaf', 'Controller': 'component', 'MPCController': 'Composite', 'LonController': 'Composite'}
# {'MPCController': 'Leaf', 'Controller': 'component', 'LatController': 'Composite', 'LonController': 'Composite'}

# %% [markdown]
# ### Storage

# %%
pickle.dump(pruned_planning_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_planning.p','wb'))
pickle.dump(pruned_ctrl_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_control.p','wb'))
pickle.dump(pattern,open('../Data/design_patterns/'+pattern_name+'.p','wb'))
pickle.dump(fixed_parts,open('../Data/design_patterns/'+pattern_name+'_fixed.p','wb'))
