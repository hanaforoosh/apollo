# %% [markdown]
# ### Imports

# %%
import networkx as nx
import networkx.algorithms.isomorphism as iso
import pickle
from functools import reduce

# %% [markdown]
# ### Graphs initialization

# %%
# main (code) graph
ctrl = pickle.load(open('../Data/ctrl_graph.p','rb'))
planning = pickle.load(open('../Data/planning_graph.p','rb'))

# %% [markdown]
# ### 1. Change this
# # ↓↓↓   ↓↓↓

# %%
pattern_name='Command'
pattern = nx.DiGraph()
pattern.add_edge('Invoker','Command',type='Association')
pattern.add_edge('Command1','Command',type='Generalization')

# %% [markdown]
# ### Graphs visualizations [Optional]

# %%
# ctrl graph
pos=nx.spring_layout(ctrl)
nx.draw_networkx_edge_labels(ctrl,pos)
nx.draw(ctrl,pos,with_labels=True)

# %%
# planning graph
pos=nx.spring_layout(planning)
nx.draw_networkx_edge_labels(planning,pos)
nx.draw(planning,pos,with_labels=True)

# %%
# pattern graph
pos=nx.spring_layout(pattern)
nx.draw_networkx_edge_labels(pattern,pos)
nx.draw(pattern,pos,with_labels=True)

# %% [markdown]
# ### Finding matched patterns

# %%
# in ctrl graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
ctrl_DiGM = iso.DiGraphMatcher(ctrl,pattern,edge_match=nm)
#ctrl_DiGM.subgraph_is_isomorphic()
ctrl_subgraphs = [graph for graph in ctrl_DiGM.subgraph_isomorphisms_iter()]
print (ctrl_subgraphs)
# Out:
# [{'TrajectoryAnalyzer': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}, {'TrajectoryAnalyzer': 'Invoker', 'MPCController': 'Command', 'MPCControllerTest': 'Command1'}, {'ControlComponent': 'Invoker', 'ControlTestBase': 'Command', 'SimpleControlTest': 'Command1'}, {'ControlComponent': 'Invoker', 'ControlTestBase': 'Command', 'MPCControllerTest': 'Command1'}, {'ControlComponent': 'Invoker', 'ControlTestBase': 'Command', 'RelativePositionTest': 'Command1'}, {'PIDController': 'Invoker', 'LonController': 'Command', 'LonControllerTest': 'Command1'}, {'LeadlagController': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}, {'LeadlagController': 'Invoker', 'LonController': 'Command', 'LonControllerTest': 'Command1'}, {'MracController': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}]

# %%
# in planning graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
planning_DiGM = iso.DiGraphMatcher(planning,pattern,edge_match=nm)
#planning_DiGM.subgraph_is_isomorphic()
planning_subgraphs = [graph for graph in planning_DiGM.subgraph_isomorphisms_iter()]
print (planning_subgraphs)
# Out:
# [{'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'EmergencyStopScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'StopSignUnprotectedScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'TestLearningModelScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'LaneFollowScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'ValetParkingScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'BareIntersectionUnprotectedScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'NarrowStreetUTurnScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'TrafficLightProtectedScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'YieldSignScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'TrafficLightUnprotectedRightTurnScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'TrafficLightUnprotectedLeftTurnScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'ParkAndGoScenario': 'Command1'}, {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'PullOverScenario': 'Command1'}, {'Spline1d': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1'}, {'Spline1d': 'Invoker', 'Spline1dSolver': 'Command', 'OsqpSpline1dSolver': 'Command1'}, {'Spline2dConstraint': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1'}, {'Spline2dConstraint': 'Invoker', 'Spline2dSolver': 'Command', 'ActiveSetSpline2dSolver': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'StopSignUnprotectedScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'EmergencyStopScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'TestLearningModelScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'LaneFollowScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'ValetParkingScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'BareIntersectionUnprotectedScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'NarrowStreetUTurnScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'TrafficLightProtectedScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'YieldSignScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'TrafficLightUnprotectedRightTurnScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'TrafficLightUnprotectedLeftTurnScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'ParkAndGoScenario': 'Command1'}, {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'PullOverScenario': 'Command1'}, {'Spline2dKernel': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1'}, {'Spline2dKernel': 'Invoker', 'Spline2dSolver': 'Command', 'ActiveSetSpline2dSolver': 'Command1'}, {'Frame': 'Invoker', 'NaviTask': 'Command', 'NaviSpeedDecider': 'Command1'}, {'Frame': 'Invoker', 'NaviTask': 'Command', 'NaviObstacleDecider': 'Command1'}, {'Frame': 'Invoker', 'NaviTask': 'Command', 'NaviPathDecider': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'SpeedDecider': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'RssDecider': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'TrajectoryOptimizer': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'PathOptimizer': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'Decider': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'SpeedOptimizer': 'Command1'}, {'Frame': 'Invoker', 'Task': 'Command', 'PathDecider': 'Command1'}, {'ReferenceLineInfo': 'I ...

# %% [markdown]
# ### Merge patterns

# %%
# function definitions
def get_key(val,l): 
    for key, value in l.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

def mergeList(subList,pat):
    result=[]
    while(len(subList)>0):
        res1 = []
        res1.append(subList[0])
        for j in range(1,len(subList)):
            flag = True
            for k in pat:
                if(get_key(k,subList[0])!=get_key(k,subList[j])):
                    flag = False
            if(flag==True):
                res1.append(subList[j])
        result.append(res1)
        l3 = [x for x in subList if x not in res1]
        subList = l3
    return result

def merge(disconnected_patterns,fixed):
    lst = mergeList(disconnected_patterns,fixed)
    return list(map(lambda item: dict(item[0],**item[1]) if len(item)>1 else item[0],lst))

# %% [markdown]
# ### 2. Change this
# # ↓↓↓   ↓↓↓

# %%
fixed_parts ={'Invoker','Command'}

# %%
final_planning_subgraphs=merge(planning_subgraphs,fixed_parts)
final_ctrl_subgraphs=merge(ctrl_subgraphs,fixed_parts)
print('planning :\n',*final_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*final_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1', 'EmergencyStopScenario': 'Command1'}
# {'Spline1d': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'Spline2dConstraint': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1', 'StopSignUnprotectedScenario': 'Command1'}
# {'Spline2dKernel': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'Frame': 'Invoker', 'NaviTask': 'Command', 'NaviSpeedDecider': 'Command1', 'NaviObstacleDecider': 'Command1'}
# {'Frame': 'Invoker', 'Task': 'Command', 'SpeedDecider': 'Command1', 'RssDecider': 'Command1'}
# {'ReferenceLineInfo': 'Invoker', 'Task': 'Command', 'SpeedDecider': 'Command1', 'RssDecider': 'Command1'}
# {'ReferenceLineInfo': 'Invoker', 'NaviTask': 'Command', 'NaviSpeedDecider': 'Command1', 'NaviObstacleDecider': 'Command1'}
# {'Spline2d': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'Spline1dKernel': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'Spline1dConstraint': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'LocalView': 'Invoker', 'PlanningBase': 'Command', 'OnLanePlanning': 'Command1', 'NaviPlanning': 'Command1'}
# {'LocalView': 'Invoker', 'PlanningTestBase': 'Command', 'GarageTest': 'Command1', 'SunnyvaleLoopTest': 'Command1'}
#
#
# Control :
#
# {'TrajectoryAnalyzer': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}
# {'TrajectoryAnalyzer': 'Invoker', 'MPCController': 'Command', 'MPCControllerTest': 'Command1'}
# {'ControlComponent': 'Invoker', 'ControlTestBase': 'Command', 'SimpleControlTest': 'Command1', 'MPCControllerTest': 'Command1'}
# {'PIDController': 'Invoker', 'LonController': 'Command', 'LonControllerTest': 'Command1'}
# {'LeadlagController': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}
# {'LeadlagController': 'Invoker', 'LonController': 'Command', 'LonControllerTest': 'Command1'}
# {'MracController': 'Invoker', 'LatController': 'Command', 'LatControllerTest': 'Command1'}

# %% [markdown]
# ### Pruning

# %%
variable_parts = set(pattern.nodes())-fixed_parts
pruned_planning_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_planning_subgraphs))
pruned_ctrl_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_ctrl_subgraphs))
print('planning :\n',*pruned_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*pruned_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'ScenarioContext': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1', 'EmergencyStopScenario': 'Command1'}
# {'Spline1d': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'Spline2dConstraint': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'ScenarioStatus': 'Invoker', 'Scenario': 'Command', 'EmergencyPullOverScenario': 'Command1', 'StopSignUnprotectedScenario': 'Command1'}
# {'Spline2dKernel': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'Frame': 'Invoker', 'NaviTask': 'Command', 'NaviSpeedDecider': 'Command1', 'NaviObstacleDecider': 'Command1'}
# {'Frame': 'Invoker', 'Task': 'Command', 'SpeedDecider': 'Command1', 'RssDecider': 'Command1'}
# {'ReferenceLineInfo': 'Invoker', 'Task': 'Command', 'SpeedDecider': 'Command1', 'RssDecider': 'Command1'}
# {'ReferenceLineInfo': 'Invoker', 'NaviTask': 'Command', 'NaviSpeedDecider': 'Command1', 'NaviObstacleDecider': 'Command1'}
# {'Spline2d': 'Invoker', 'Spline2dSolver': 'Command', 'OsqpSpline2dSolver': 'Command1', 'ActiveSetSpline2dSolver': 'Command1'}
# {'Spline1dKernel': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'Spline1dConstraint': 'Invoker', 'Spline1dSolver': 'Command', 'ActiveSetSpline1dSolver': 'Command1', 'OsqpSpline1dSolver': 'Command1'}
# {'LocalView': 'Invoker', 'PlanningBase': 'Command', 'OnLanePlanning': 'Command1', 'NaviPlanning': 'Command1'}
# {'LocalView': 'Invoker', 'PlanningTestBase': 'Command', 'GarageTest': 'Command1', 'SunnyvaleLoopTest': 'Command1'}
#
#
# Control :
#
# {'ControlComponent': 'Invoker', 'ControlTestBase': 'Command', 'SimpleControlTest': 'Command1', 'MPCControllerTest': 'Command1'}

# %% [markdown]
# ### Storage

# %%
pickle.dump(pruned_planning_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_planning.p','wb'))
pickle.dump(pruned_ctrl_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_control.p','wb'))
pickle.dump(pattern,open('../Data/design_patterns/'+pattern_name+'.p','wb'))
pickle.dump(fixed_parts,open('../Data/design_patterns/'+pattern_name+'_fixed.p','wb'))
