# %% [markdown]
# ### Imports

# %%
import networkx as nx
import networkx.algorithms.isomorphism as iso
import pickle
from functools import reduce

# %% [markdown]
# ### Graphs initialization

# %%
# main (code) graph
ctrl = pickle.load(open('../Data/ctrl_graph.p','rb'))
planning = pickle.load(open('../Data/planning_graph.p','rb'))

# %% [markdown]
# ### 1. Change this
# # ↓↓↓   ↓↓↓

# %%
pattern_name='NullObject'
pattern = nx.DiGraph()
pattern.add_edge('Context','AbstractlObject',type='Association')
pattern.add_edge('NullObjects','AbstractlObject',type='Generalization')
pattern.add_edge('RealObjects','AbstractlObject',type='Generalization')

# %% [markdown]
# ### Graphs visualizations [Optional]

# %%
# ctrl graph
pos=nx.spring_layout(ctrl)
nx.draw_networkx_edge_labels(ctrl,pos)
nx.draw(ctrl,pos,with_labels=True)

# %%
# planning graph
pos=nx.spring_layout(planning)
nx.draw_networkx_edge_labels(planning,pos)
nx.draw(planning,pos,with_labels=True)

# %%
# pattern graph
pos=nx.spring_layout(pattern)
nx.draw_networkx_edge_labels(pattern,pos)
nx.draw(pattern,pos,with_labels=True)

# %% [markdown]
# ### Finding matched patterns

# %%
# in ctrl graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
ctrl_DiGM = iso.DiGraphMatcher(ctrl,pattern,edge_match=nm)
#ctrl_DiGM.subgraph_is_isomorphic()
ctrl_subgraphs = [graph for graph in ctrl_DiGM.subgraph_isomorphisms_iter()]
print (ctrl_subgraphs)
# Out:
# [{'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}, {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}, {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}, {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}, {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}, {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}]

# %%
# in planning graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
planning_DiGM = iso.DiGraphMatcher(planning,pattern,edge_match=nm)
#planning_DiGM.subgraph_is_isomorphic()
planning_subgraphs = [graph for graph in planning_DiGM.subgraph_isomorphisms_iter()]
print (planning_subgraphs)
# Out:
# [{'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}, {'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}, {'ScenarioContext': 'Context', 'Sce ...

# %% [markdown]
# ### Merge patterns

# %%
# function definitions
def get_key(val,l): 
    for key, value in l.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

def mergeList(subList,pat):
    result=[]
    while(len(subList)>0):
        res1 = []
        res1.append(subList[0])
        for j in range(1,len(subList)):
            flag = True
            for k in pat:
                if(get_key(k,subList[0])!=get_key(k,subList[j])):
                    flag = False
            if(flag==True):
                res1.append(subList[j])
        result.append(res1)
        l3 = [x for x in subList if x not in res1]
        subList = l3
    return result

def merge(disconnected_patterns,fixed):
    lst = mergeList(disconnected_patterns,fixed)
    return list(map(lambda item: dict(item[0],**item[1]) if len(item)>1 else item[0],lst))

# %% [markdown]
# ### 2. Change this
# # ↓↓↓   ↓↓↓

# %%
fixed_parts ={'Context','AbstractlObject','NullObjects','RealObjects'}

# %%
final_planning_subgraphs=merge(planning_subgraphs,fixed_parts)
final_ctrl_subgraphs=merge(ctrl_subgraphs,fixed_parts)
print('planning :\n',*final_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*final_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# ...
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'Spline1d': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1d': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'Spline1dConstraint': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'Spline1dConstraint': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1dKernel': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1dKernel': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'NaviTask': 'AbstractlObject', 'NaviPathDecider': 'NullObjects', 'NaviSpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'NaviTask': 'AbstractlObject', 'NaviSpeedDecider': 'NullObjects', 'NaviPathDecider': 'RealObjects'}
# {'Spline2dKernel': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2dKernel': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'Spline2dConstraint': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2dConstraint': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'Frame': 'Context', 'NaviTask': 'AbstractlObject', 'NaviPathDecider': 'NullObjects', 'NaviSpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'NaviTask': 'AbstractlObject', 'NaviSpeedDecider': 'NullObjects', 'NaviPathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningBase': 'AbstractlObject', 'OnLanePlanning': 'NullObjects', 'NaviPlanning': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningBase': 'AbstractlObject', 'NaviPlanning': 'NullObjects', 'OnLanePlanning': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'GarageTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'GarageTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'GarageTest': 'RealObjects'}
#
#
# Control :
#
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}

# %% [markdown]
# ### Pruning

# %%
variable_parts = set(pattern.nodes())-fixed_parts
pruned_planning_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_planning_subgraphs))
pruned_ctrl_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_ctrl_subgraphs))
print('planning :\n',*pruned_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*pruned_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2d': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'ValetParkingScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'BareIntersectionUnprotectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioContext': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'NarrowStreetUTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'PullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyStopScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TestLearningModelScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'EmergencyPullOverScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'ParkAndGoScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightProtectedScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'YieldSignScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'LaneFollowScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedRightTurnScenario': 'NullObjects', 'StopSignUnprotectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'NarrowStreetUTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'PullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyStopScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'TestLearningModelScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'TrafficLightUnprotectedLeftTurnScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# ...
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'EmergencyPullOverScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ParkAndGoScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightProtectedScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'YieldSignScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'LaneFollowScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedRightTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'TrafficLightUnprotectedLeftTurnScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'ValetParkingScenario': 'RealObjects'}
# {'ScenarioStatus': 'Context', 'Scenario': 'AbstractlObject', 'StopSignUnprotectedScenario': 'NullObjects', 'BareIntersectionUnprotectedScenario': 'RealObjects'}
# {'Spline1d': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1d': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'Spline1dConstraint': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'Spline1dConstraint': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1dKernel': 'Context', 'Spline1dSolver': 'AbstractlObject', 'ActiveSetSpline1dSolver': 'NullObjects', 'OsqpSpline1dSolver': 'RealObjects'}
# {'Spline1dKernel': 'Context', 'Spline1dSolver': 'AbstractlObject', 'OsqpSpline1dSolver': 'NullObjects', 'ActiveSetSpline1dSolver': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'NaviTask': 'AbstractlObject', 'NaviPathDecider': 'NullObjects', 'NaviSpeedDecider': 'RealObjects'}
# {'ReferenceLineInfo': 'Context', 'NaviTask': 'AbstractlObject', 'NaviSpeedDecider': 'NullObjects', 'NaviPathDecider': 'RealObjects'}
# {'Spline2dKernel': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2dKernel': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'Spline2dConstraint': 'Context', 'Spline2dSolver': 'AbstractlObject', 'OsqpSpline2dSolver': 'NullObjects', 'ActiveSetSpline2dSolver': 'RealObjects'}
# {'Spline2dConstraint': 'Context', 'Spline2dSolver': 'AbstractlObject', 'ActiveSetSpline2dSolver': 'NullObjects', 'OsqpSpline2dSolver': 'RealObjects'}
# {'Frame': 'Context', 'NaviTask': 'AbstractlObject', 'NaviPathDecider': 'NullObjects', 'NaviSpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'NaviTask': 'AbstractlObject', 'NaviSpeedDecider': 'NullObjects', 'NaviPathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'Decider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'PathDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'RssDecider': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'TrajectoryOptimizer': 'NullObjects', 'SpeedDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'Decider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'PathDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'RssDecider': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'SpeedOptimizer': 'RealObjects'}
# {'Frame': 'Context', 'Task': 'AbstractlObject', 'SpeedDecider': 'NullObjects', 'TrajectoryOptimizer': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningBase': 'AbstractlObject', 'OnLanePlanning': 'NullObjects', 'NaviPlanning': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningBase': 'AbstractlObject', 'NaviPlanning': 'NullObjects', 'OnLanePlanning': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'GarageTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleBigLoopTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'GarageTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'NavigationModeTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'GarageTest': 'NullObjects', 'SunnyvaleLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'SunnyvaleBigLoopTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'NavigationModeTest': 'RealObjects'}
# {'LocalView': 'Context', 'PlanningTestBase': 'AbstractlObject', 'SunnyvaleLoopTest': 'NullObjects', 'GarageTest': 'RealObjects'}
#
#
# Control :
#
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'MPCControllerTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'SimpleControlTest': 'NullObjects', 'RelativePositionTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'MPCControllerTest': 'RealObjects'}
# {'ControlComponent': 'Context', 'ControlTestBase': 'AbstractlObject', 'RelativePositionTest': 'NullObjects', 'SimpleControlTest': 'RealObjects'}

# %% [markdown]
# ### Storage

# %%
pickle.dump(pruned_planning_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_planning.p','wb'))
pickle.dump(pruned_ctrl_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_control.p','wb'))
pickle.dump(pattern,open('../Data/design_patterns/'+pattern_name+'.p','wb'))
pickle.dump(fixed_parts,open('../Data/design_patterns/'+pattern_name+'_fixed.p','wb'))
