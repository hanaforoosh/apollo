# %% [markdown]
# ### Imports

# %%
import networkx as nx
import networkx.algorithms.isomorphism as iso
import pickle
from functools import reduce

# %% [markdown]
# ### Graphs initialization

# %%
# main (code) graph
ctrl = pickle.load(open('../Data/ctrl_graph.p','rb'))
planning = pickle.load(open('../Data/planning_graph.p','rb'))

# %% [markdown]
# ### 1. Change this
# # ↓↓↓   ↓↓↓

# %%
pattern_name='Facade'
pattern = nx.DiGraph()
pattern.add_edge('Facade','AdditionalFacade',type='Association')
pattern.add_edge('Facade','Subsystemclass',type='Association')
pattern.add_edge('AdditionalFacade','AnotherSubsystemclass',type='Association')

# %% [markdown]
# ### Graphs visualizations [Optional]

# %%
# ctrl graph
pos=nx.spring_layout(ctrl)
nx.draw_networkx_edge_labels(ctrl,pos)
nx.draw(ctrl,pos,with_labels=True)

# %%
# planning graph
pos=nx.spring_layout(planning)
nx.draw_networkx_edge_labels(planning,pos)
nx.draw(planning,pos,with_labels=True)

# %%
# pattern graph
pos=nx.spring_layout(pattern)
nx.draw_networkx_edge_labels(pattern,pos)
nx.draw(pattern,pos,with_labels=True)

# %% [markdown]
# ### Finding matched patterns

# %%
# in ctrl graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
ctrl_DiGM = iso.DiGraphMatcher(ctrl,pattern,edge_match=nm)
#ctrl_DiGM.subgraph_is_isomorphic()
ctrl_subgraphs = [graph for graph in ctrl_DiGM.subgraph_isomorphisms_iter()]
print (ctrl_subgraphs)
# Out:
# [{'TrajectoryAnalyzer': 'Facade', 'LatController': 'AdditionalFacade', 'MPCController': 'Subsystemclass', 'LatLonControllerSubmodule': 'AnotherSubsystemclass'}, {'TrajectoryAnalyzer': 'Facade', 'MPCController': 'AdditionalFacade', 'LatController': 'Subsystemclass', 'MPCControllerSubmodule': 'AnotherSubsystemclass'}]

# %%
# in planning graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
planning_DiGM = iso.DiGraphMatcher(planning,pattern,edge_match=nm)
#planning_DiGM.subgraph_is_isomorphic()
planning_subgraphs = [graph for graph in planning_DiGM.subgraph_isomorphisms_iter()]
print (planning_subgraphs)
# Out:
# [{'History': 'Facade', 'STObstaclesProcessor': 'AdditionalFacade', 'PathReuseDecider': 'Subsystemclass', 'STBoundsDecider': 'AnotherSubsystemclass'}, {'History': 'Facade', 'STObstaclesProcessor': 'AdditionalFacade', 'HistoryTest': 'Subsystemclass', 'STBoundsDecider': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'Rerouting': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'CollisionChecker': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'Task': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'Frame': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'WaypointSampler': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'NaviTask': 'AnotherSubsystemclass'}, {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'PathTimeGraph': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'StBoundaryMapperTest': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'STObstaclesProcessor': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'StBoundaryMapperTest': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'STObstaclesProcessor': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'SmootherUtil': 'Subsystemclass', 'StBoundaryMapperTest': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'SmootherUtil': 'Subsystemclass', 'STObstaclesProcessor': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'Rerouting': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'CollisionChecker': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'Frame': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'NaviTask': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'WaypointSampler': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'PathTimeGraph': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'Rerouting': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'CollisionChecker': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'TrajectoryCost': 'Subsystemclass', 'Task': 'AnotherSubsystemclass'}, {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'TrajectoryCos ...

# %% [markdown]
# ### Merge patterns

# %%
# function definitions
def get_key(val,l): 
    for key, value in l.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

def mergeList(subList,pat):
    result=[]
    while(len(subList)>0):
        res1 = []
        res1.append(subList[0])
        for j in range(1,len(subList)):
            flag = True
            for k in pat:
                if(get_key(k,subList[0])!=get_key(k,subList[j])):
                    flag = False
            if(flag==True):
                res1.append(subList[j])
        result.append(res1)
        l3 = [x for x in subList if x not in res1]
        subList = l3
    return result

def merge(disconnected_patterns,fixed):
    lst = mergeList(disconnected_patterns,fixed)
    return list(map(lambda item: dict(item[0],**item[1]) if len(item)>1 else item[0],lst))

# %% [markdown]
# ### 2. Change this
# # ↓↓↓   ↓↓↓

# %%
fixed_parts ={'AdditionalFacade','Facade'}

# %%
final_planning_subgraphs=merge(planning_subgraphs,fixed_parts)
final_ctrl_subgraphs=merge(ctrl_subgraphs,fixed_parts)
print('planning :\n',*final_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*final_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'History': 'Facade', 'STObstaclesProcessor': 'AdditionalFacade', 'PathReuseDecider': 'Subsystemclass', 'STBoundsDecider': 'AnotherSubsystemclass', 'HistoryTest': 'Subsystemclass'}
# {'StGraphData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpStGraphTest': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'ReferenceLine': 'Facade', 'PathData': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'StBoundaryMapperTest': 'AnotherSubsystemclass', 'STObstaclesProcessor': 'AnotherSubsystemclass'}
# {'ReferenceLine': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'SpeedDecider': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'ReferenceLine': 'Facade', 'TrajectoryCost': 'AdditionalFacade', 'PathData': 'Subsystemclass', 'RoadGraphMessage': 'AnotherSubsystemclass', 'ReferenceLineInfo': 'Subsystemclass'}
# {'OpenSpaceInfo': 'Facade', 'Frame': 'AdditionalFacade', 'OpenSpaceInfoTest': 'Subsystemclass', 'Task': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'SpeedData': 'Facade', 'TrajectoryCost': 'AdditionalFacade', 'DpRoadGraph': 'Subsystemclass', 'RoadGraphMessage': 'AnotherSubsystemclass', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Subsystemclass'}
# {'SpeedData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'DpRoadGraph': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'DiscretizedPath': 'Facade', 'Frame': 'AdditionalFacade', 'PathData': 'Subsystemclass', 'Task': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'DiscretizedPath': 'Facade', 'PathData': 'AdditionalFacade', 'Frame': 'Subsystemclass', 'StBoundaryMapperTest': 'AnotherSubsystemclass', 'STObstaclesProcessor': 'AnotherSubsystemclass'}
# {'PathDecision': 'Facade', 'STObstaclesProcessor': 'AdditionalFacade', 'ReferenceLineInfo': 'Subsystemclass', 'STBoundsDecider': 'AnotherSubsystemclass'}
# {'PathDecision': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'STObstaclesProcessor': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'SpeedLimit': 'Facade', 'StGraphData': 'AdditionalFacade', 'PiecewiseJerkSpeedNonlinearOptimizer': 'Subsystemclass', 'ReferenceLineInfo': 'AnotherSubsystemclass', 'SpeedLimitTest': 'Subsystemclass'}
# {'PathData': 'Facade', 'STObstaclesProcessor': 'AdditionalFacade', 'StBoundaryMapperTest': 'Subsystemclass', 'STBoundsDecider': 'AnotherSubsystemclass', 'ReferenceLineInfo': 'Subsystemclass'}
# {'PathData': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'StBoundaryMapperTest': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'STPoint': 'Facade', 'STBoundary': 'AdditionalFacade', 'SamplePoint': 'Subsystemclass', 'Obstacle': 'AnotherSubsystemclass'}
# {'LocalView': 'Facade', 'Frame': 'AdditionalFacade', 'PlanningComponent': 'Subsystemclass', 'Rerouting': 'AnotherSubsystemclass', 'Task': 'AnotherSubsystemclass'}
# {'DiscretizedTrajectory': 'Facade', 'ReferenceLineInfo': 'AdditionalFacade', 'OpenSpaceInfo': 'Subsystemclass', 'ReferenceLineInfoTest': 'AnotherSubsystemclass', 'Rerouting': 'AnotherSubsystemclass'}
# {'DiscretizedTrajectory': 'Facade', 'OpenSpaceInfo': 'AdditionalFacade', 'ReferenceLineInfo': 'Subsystemclass', 'OpenSpaceInfoTest': 'AnotherSubsystemclass', 'OpenSpaceTrajectoryOptimizer': 'Subsystemclass', 'Frame': 'AnotherSubsystemclass'}
# {'AffineConstraint': 'Facade', 'Spline2dConstraint': 'AdditionalFacade', 'Spline1dConstraint': 'Subsystemclass', 'Spline2dSolver': 'AnotherSubsystemclass'}
# {'AffineConstraint': 'Facade', 'Spline1dConstraint': 'AdditionalFacade', 'Spline2dConstraint': 'Subsystemclass', 'Spline1dSolver': 'AnotherSubsystemclass'}
#
#
# Control :
#
# {'TrajectoryAnalyzer': 'Facade', 'LatController': 'AdditionalFacade', 'MPCController': 'Subsystemclass', 'LatLonControllerSubmodule': 'AnotherSubsystemclass'}
# {'TrajectoryAnalyzer': 'Facade', 'MPCController': 'AdditionalFacade', 'LatController': 'Subsystemclass', 'MPCControllerSubmodule': 'AnotherSubsystemclass'}

# %% [markdown]
# ### Pruning

# %%
variable_parts = set(pattern.nodes())-fixed_parts
pruned_planning_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_planning_subgraphs))
pruned_ctrl_subgraphs=list(filter(lambda pattern: len(pattern)>=len(fixed_parts)+2*len(variable_parts),final_ctrl_subgraphs))
print('planning :\n',*pruned_planning_subgraphs,sep='\n')
print('\n')
print('Control :\n',*pruned_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'DiscretizedTrajectory': 'Facade', 'OpenSpaceInfo': 'AdditionalFacade', 'ReferenceLineInfo': 'Subsystemclass', 'OpenSpaceInfoTest': 'AnotherSubsystemclass', 'OpenSpaceTrajectoryOptimizer': 'Subsystemclass', 'Frame': 'AnotherSubsystemclass'}
#
#
# Control :

# %% [markdown]
# ### Storage

# %%
pickle.dump(pruned_planning_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_planning.p','wb'))
pickle.dump(pruned_ctrl_subgraphs,open('../Data/Found_patterns/'+pattern_name+'_control.p','wb'))
pickle.dump(pattern,open('../Data/design_patterns/'+pattern_name+'.p','wb'))
pickle.dump(fixed_parts,open('../Data/design_patterns/'+pattern_name+'_fixed.p','wb'))
