# %% [markdown]
# ### Imports

# %%
import networkx as nx
import networkx.algorithms.isomorphism as iso
import pickle
from functools import reduce

# %% [markdown]
# ### Graphs initialization

# %%
# main (code) graph
ctrl = pickle.load(open('../Data/ctrl_graph.p','rb'))
planning = pickle.load(open('../Data/planning_graph.p','rb'))

# %% [markdown]
# ### 1. Change this
# # ↓↓↓   ↓↓↓

# %%
# Strategy patten
pattern = nx.DiGraph()
pattern.add_edge(1,2,type='Association')
pattern.add_edge(3,2,type='Generalization')

# %% [markdown]
# ### Graphs visualizations [Optional]

# %%
# ctrl graph
pos=nx.spring_layout(ctrl)
nx.draw_networkx_edge_labels(ctrl,pos)
nx.draw(ctrl,pos,with_labels=True)

# %%
# planning graph
pos=nx.spring_layout(planning)
nx.draw_networkx_edge_labels(planning,pos)
nx.draw(planning,pos,with_labels=True)

# %%
# pattern graph
pos=nx.spring_layout(pattern)
nx.draw_networkx_edge_labels(pattern,pos)
nx.draw(pattern,pos,with_labels=True)

# %% [markdown]
# ### Finding matched patterns

# %%
# in ctrl graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
ctrl_DiGM = iso.DiGraphMatcher(ctrl,pattern,edge_match=nm)
#ctrl_DiGM.subgraph_is_isomorphic()
ctrl_subgraphs = [graph for graph in ctrl_DiGM.subgraph_isomorphisms_iter()]
print (ctrl_subgraphs)
# Out:
# [{'LonController': 1, 'PIDController': 2, 'PIDICController': 3}, {'LonController': 1, 'PIDController': 2, 'PIDBCController': 3}]

# %%
# in planning graph
import networkx.algorithms.isomorphism as iso
nm = iso.categorical_edge_match('type', 'xyz')
planning_DiGM = iso.DiGraphMatcher(planning,pattern,edge_match=nm)
#planning_DiGM.subgraph_is_isomorphic()
planning_subgraphs = [graph for graph in planning_DiGM.subgraph_isomorphisms_iter()]
print (planning_subgraphs)
# Out:
# [{'PathDecision': 1, 'IndexedList': 2, 'ThreadSafeIndexedList': 3}, {'PathDecision': 1, 'IndexedList': 2, 'IndexedObstacles': 3}, {'ReferenceLineInfo': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}, {'OpenSpaceTrajectoryOptimizer': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}, {'OpenSpaceInfo': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}, {'DpRoadGraphNode': 1, 'QuinticPolynomialCurve1d': 2, 'QuinticSpiralPathWithDerivation': 3}, {'DpRoadGraphNode': 1, 'QuinticPolynomialCurve1d': 2, 'QuinticSpiralPath': 3}]

# %% [markdown]
# ### Merge patterns

# %%
# function definitions
def get_key(val,l): 
    for key, value in l.items(): 
         if val == value: 
             return key 
  
    return "key doesn't exist"

def mergeList(subList,pat):
    result=[]
    while(len(subList)>0):
        res1 = []
        res1.append(subList[0])
        for j in range(1,len(subList)):
            flag = True
            for k in pat:
                if(get_key(k,subList[0])!=get_key(k,subList[j])):
                    flag = False
            if(flag==True):
                res1.append(subList[j])
        result.append(res1)
        l3 = [x for x in subList if x not in res1]
        subList = l3
    return result

def merge(disconnected_patterns,fixed):
    lst = mergeList(disconnected_patterns,fixed)
    return list(map(lambda item: dict(item[0],**item[1]) if len(item)>1 else item[0],lst))

# %% [markdown]
# ### 2. Change this
# # ↓↓↓   ↓↓↓

# %%
fixed_parts ={1,2}

# %%
final_planning_subgraphs=merge(planning_subgraphs,fixed_parts)
final_ctrl_subgraphs=merge(ctrl_subgraphs,fixed_parts)
print('planning :\n',*final_planning_subgraphs,sep='\n')
print('\n\n')
print('Control :\n',*final_ctrl_subgraphs,sep='\n')
# Out:
# planning :
#
# {'PathDecision': 1, 'IndexedList': 2, 'ThreadSafeIndexedList': 3, 'IndexedObstacles': 3}
# {'ReferenceLineInfo': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}
# {'OpenSpaceTrajectoryOptimizer': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}
# {'OpenSpaceInfo': 1, 'DiscretizedTrajectory': 2, 'PublishableTrajectory': 3}
# {'DpRoadGraphNode': 1, 'QuinticPolynomialCurve1d': 2, 'QuinticSpiralPathWithDerivation': 3, 'QuinticSpiralPath': 3}
#
#
#
# Control :
#
# {'LonController': 1, 'PIDController': 2, 'PIDICController': 3, 'PIDBCController': 3}
